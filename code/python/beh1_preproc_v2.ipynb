# %% [markdown]
# ### Logic flow
# * Concat patient dfs, separately for old vs new versions
#     * Old
#         * Create cols ‘shape_direction’, ‘true_thresh’
#         * Create ‘valence_direction’, which=1 when curv=penalty & flat=reward and -1 when curv=reward & flat=penalty.
#             * Assert that for these older versions, sessions AC were always = 1 and BD were always = -1
#     * New
#     * Combined
#         * Rename cols
#         * Rename subjects
#         * Create ‘target_resp’=final slider position, ‘true_resp’= accounting for shape_direction
#             * Need to first type-cast
#         * Flip variable depending on valence_direction, and appropriately prefix these new variables
#         * Create new cols
#             * Boundary-aligned variables, positional_ranks
#         * Sanity checks
#             * Error trials, timings, Outcomes
#
#     * save data/psychopy/all_beh_trials_df.csv

# %%
import matplotlib.pyplot as plt, numpy as np, seaborn as sns, scipy.stats as stats, pandas as pd, os, glob
import ast
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### 1. preprocess old versions

# %%
# create concatenated df
df_v1 = pd.DataFrame()

for subj_file in glob.glob('../../data/psychopy/asymmetry_final_subj*.csv'):
    df_subj = pd.read_csv(subj_file)[:240]
    df_v1 = pd.concat([df_v1, df_subj], ignore_index=True)

print(f'subjs: {df_v1["subj"].unique()}')
df_v1
# Out:
# subjs: [202509. 202511. 202512. 202521. 202522. 202518.]
#       thisN  thisTrialN  thisRepN  blockN  run  condition  trial_key  \
# 0       0.0         0.0       0.0     1.0  1.0   baseline       10.0
# 1       1.0         1.0       0.0     1.0  1.0   baseline        7.0
# 2       2.0         2.0       0.0     1.0  1.0   baseline       37.0
# 3       3.0         3.0       0.0     1.0  1.0   baseline       14.0
# 4       4.0         4.0       0.0     1.0  1.0   baseline        8.0
# ...     ...         ...       ...     ...  ...        ...        ...
# 1435   35.0        35.0       0.0     6.0  2.0  flat_comp      236.0
# 1436   36.0        36.0       0.0     6.0  2.0  flat_comp      226.0
# 1437   37.0        37.0       0.0     6.0  2.0  flat_comp      223.0
# 1438   38.0        38.0       0.0     6.0  2.0  flat_comp      218.0
# 1439   39.0        39.0       0.0     6.0  2.0  flat_comp      239.0
#
#       stim_file_pos  stim_pos  noise_pos  ...      subj difficulty sess_type  \
# ...

# %%
df_v1['shape_direction'] = df_v1['shape_order'].map({'curv_flat': 1, 'flat_curv': -1})
df_v1['true_thresh'] = np.where( df_v1['shape_direction'] == -1, -df_v1['div_pos'], df_v1['div_pos'] ) 

df_v1[['shape_order', 'shape_direction', 'true_thresh']].head(5)
# Out:
#   shape_order  shape_direction  true_thresh
# 0   curv_flat                1          0.0
# 1   flat_curv               -1         -0.0
# 2   flat_curv               -1         -0.0
# 3   curv_flat                1          0.0
# 4   curv_flat                1          0.0

# %% [markdown]
# valence flipping entire sessions because we didnt counterbalance halfway

# %%
# valence_direction: 1 when curv=pen & flat=rew, -1 when curv=rew & flat=pen
df_v1['valence_direction'] = np.where( ((df_v1['shape'] == 'curv') & (df_v1['valence'] == 'pen')) |
                                       ((df_v1['shape'] == 'flat') & (df_v1['valence'] == 'rew')), 1, -1 )

# older versions didn't counterbalance halfway: valence mapping is fixed per session type
assert (df_v1[df_v1['sess_type'].isin(['A', 'C'])]['valence_direction'] == 1).all()
assert (df_v1[df_v1['sess_type'].isin(['B', 'D'])]['valence_direction'] == -1).all()

# %% [markdown]
# ### 2. preprocess new versions

# %%
# create concatenated df
df_v2 = pd.DataFrame()

for subj_file in glob.glob('../../data/psychopy/asymmetry_final_v2*.csv'):
    df_subj = pd.read_csv(subj_file)[:240]
    df_v2 = pd.concat([df_v2, df_subj], ignore_index=True)

print(f'subjs: {df_v2["subj"].unique()}')
df_v2
# Out:
# subjs: <ArrowStringArray>
# ['renee', 'sienna', 'daria', 'kahini']
# Length: 4, dtype: str
#      thisN  thisTrialN  thisRepN  blockN  run  condition  trial_key  \
# 0      0.0         0.0       0.0     4.0  2.0   baseline      150.0
# 1      1.0         1.0       0.0     4.0  2.0   baseline      141.0
# 2      2.0         2.0       0.0     4.0  2.0   baseline      151.0
# 3      3.0         3.0       0.0     4.0  2.0   baseline      157.0
# 4      4.0         4.0       0.0     4.0  2.0   baseline      154.0
# ..     ...         ...       ...     ...  ...        ...        ...
# 955   35.0        35.0       0.0     5.0  2.0  curv_comp      181.0
# 956   36.0        36.0       0.0     5.0  2.0  curv_comp      178.0
# 957   37.0        37.0       0.0     5.0  2.0  curv_comp      184.0
# 958   38.0        38.0       0.0     5.0  2.0  curv_comp      183.0
# 959   39.0        39.0       0.0     5.0  2.0  curv_comp      161.0
#
#      stim_file_pos  stim_pos  noise_pos  ...  \
# ...

# %%
# v2 psychopy already computes these at runtime; just align names with v1
df_v2 = df_v2.rename(columns={'direction': 'shape_direction', 'true_div': 'true_thresh'})

# v2's native valence_direction was just the trial's valence sign (rew=1/pen=-1); overwrite with the mapping definition
df_v2['valence_direction'] = np.where( ((df_v2['shape'] == 'curv') & (df_v2['valence'] == 'pen')) |
                                       ((df_v2['shape'] == 'flat') & (df_v2['valence'] == 'rew')), 1, -1 )

# %% [markdown]
# ### 3. combine dfs and global preprocess

# %%
df_subjs = pd.concat([df_v1, df_v2], ignore_index=True).copy()
print(df_subjs.shape)
print(f'subjs: {df_subjs["subj"].unique()}')
df_subjs.head(5)
# Out:
# (2400, 140)
# subjs: [202509.0 202511.0 202512.0 202521.0 202522.0 202518.0 'renee' 'sienna'
#  'daria' 'kahini']
#    thisN  thisTrialN  thisRepN  blockN  run condition  trial_key  \
# 0    0.0         0.0       0.0     1.0  1.0  baseline       10.0
# 1    1.0         1.0       0.0     1.0  1.0  baseline        7.0
# 2    2.0         2.0       0.0     1.0  1.0  baseline       37.0
# 3    3.0         3.0       0.0     1.0  1.0  baseline       14.0
# 4    4.0         4.0       0.0     1.0  1.0  baseline        8.0
#
#    stim_file_pos  stim_pos  noise_pos  ...  valence_instruct.started  \
# 0            1.1     -0.18        1.0  ...                       NaN
# 1            0.7     -0.26        1.0  ...                       NaN
# 2            3.7      0.34        3.0  ...                       NaN
# 3            1.5     -0.10        1.0  ...                       NaN
# 4            0.9     -0.22        1.0  ...                       NaN
#
# ...

# %%
# rename certain columns
df_subjs = df_subjs.rename(columns={'stim_pos':'true_stim', 'target_pos':'target_stim', 
                                    'true_thresh':'true_boundary', 'div_pos':'target_boundary'})

df_subjs[['condition',
          'true_stim', 'target_stim',
          'true_boundary', 'target_boundary']].head(5)
# Out:
#   condition  true_stim  target_stim  true_boundary  target_boundary
# 0  baseline      -0.18        -0.18            0.0              0.0
# 1  baseline      -0.26         0.26           -0.0              0.0
# 2  baseline       0.34        -0.34           -0.0              0.0
# 3  baseline      -0.10        -0.10            0.0              0.0
# 4  baseline      -0.22        -0.22            0.0              0.0

# %% [markdown]
# ### change subj names for pilots

# %%
# Replace string subject IDs with numeric ones
subj_mapping = {202509.0: 9, 202511.0: 11, 202512.0: 12, 202518.0: 18,
                 202521.0: 21, 202522.0: 22,
                'kahini': 1.1, 'renee': 1.11, 'daria': 1.111, 'sienna': 1.1111,
                'arnav': 2.1, 'christina': 2.11, 'albert': 2.111}
df_subjs['subj'] = df_subjs['subj'].replace(subj_mapping)
print(df_subjs['subj'].unique())
# Out:
# [9 11 12 21 22 18 1.11 1.1111 1.111 1.1]

# %%
# convert string to list (only for rows that are still strings)
# cast to object first — arrow-backed str dtype rejects list assignment
for column in ['positions']:
    df_subjs[column] = df_subjs[column].astype(object).apply(
        lambda x: ast.literal_eval(x) if isinstance(x, str) else x
    )

# Now extract last element as float
df_subjs['target_resp'] = df_subjs['positions'].apply(lambda x: float(x[-1]))

# true_resp column flips target_resp when shape_direction = -1 (flat_curv)
df_subjs['true_resp'] = np.where( df_subjs['shape_direction'] == -1, -df_subjs['target_resp'], df_subjs['target_resp'] ) 

df_subjs[['shape_order', 'shape_direction', 'target_resp', 'true_resp']].head(5)
# Out:
#   shape_order  shape_direction  target_resp  true_resp
# 0   curv_flat              1.0        0.064      0.064
# 1   flat_curv             -1.0        0.100     -0.100
# 2   flat_curv             -1.0       -0.136      0.136
# 3   curv_flat              1.0       -0.136     -0.136
# 4   curv_flat              1.0        0.056      0.056

# %% [markdown]
# Important: flip positions based on valence
# * when curvy = loss (& flat = gain), all is fine
# * when curvy = gain (& flat = loss), need to flip positions

# %%
# numeric valence per trial (rew=1, pen=0); distinct from valence_direction, which encodes the block's mapping
df_subjs['valence_numeric'] = df_subjs['valence'].map({'rew': 1, 'pen': 0})

# flip when valence_direction = -1 (curv=rew & flat=pen)
# reminder that below wont be true because of older version files
# assert ((df_subjs['valence_direction'] == -1) == (df_subjs['blockN'] >= 4)).all()

df_subjs['valence_stim'] = np.where(df_subjs['valence_direction'] == -1, -df_subjs['true_stim'], df_subjs['true_stim'])
df_subjs['valence_boundary'] = np.where(df_subjs['valence_direction'] == -1, -df_subjs['true_boundary'], df_subjs['true_boundary'])
df_subjs['valence_resp'] = np.where(df_subjs['valence_direction'] == -1, -df_subjs['true_resp'], df_subjs['true_resp'])

df_subjs[['blockN', 'shape', 'valence', 'valence_numeric',
          'true_stim', 'valence_stim',
          'true_boundary', 'valence_boundary',
          'true_resp', 'valence_resp']].head(5)
# Out:
#    blockN shape valence  valence_numeric  true_stim  valence_stim  \
# 0     1.0  curv     pen                0      -0.18         -0.18
# 1     1.0  curv     pen                0      -0.26         -0.26
# 2     1.0  flat     rew                1       0.34          0.34
# 3     1.0  curv     pen                0      -0.10         -0.10
# 4     1.0  curv     pen                0      -0.22         -0.22
#
#    true_boundary  valence_boundary  true_resp  valence_resp
# 0            0.0               0.0      0.064         0.064
# 1           -0.0              -0.0     -0.100        -0.100
# 2           -0.0              -0.0      0.136         0.136
# 3            0.0               0.0     -0.136        -0.136
# 4            0.0               0.0      0.056         0.056

# %%
# boundary alignment
df_subjs['stim_boundary_aligned'] = (df_subjs['true_stim'] - df_subjs['true_boundary']).round(3)
df_subjs['resp_boundary_aligned'] = (df_subjs['true_resp'] - df_subjs['true_boundary']).round(3)

df_subjs[['true_stim', 'true_boundary', 'stim_boundary_aligned', 'true_resp', 'resp_boundary_aligned']].tail(5)
# Out:
#       true_stim  true_boundary  stim_boundary_aligned  true_resp  \
# 2395      -0.18           -0.2                   0.02     -0.228
# 2396      -0.22           -0.2                  -0.02     -0.176
# 2397      -0.10           -0.2                   0.10     -0.188
# 2398      -0.14           -0.2                   0.06     -0.168
# 2399      -0.38           -0.2                  -0.18     -0.260
#
#       resp_boundary_aligned
# 2395                 -0.028
# 2396                  0.024
# 2397                  0.012
# 2398                  0.032
# 2399                 -0.060

# %%
# ranking positions within subj/condition, averaged across 2 blocks
grp = ['subj', 'condition']#, 'blockN']
df_subjs = df_subjs.assign(
                            rank_stim = df_subjs.groupby(grp)['true_stim'].transform('rank'),
                            rank_resp = df_subjs.groupby(grp)['true_resp'].transform('rank'),
                          ).copy()
df_subjs[['subj', 'condition', 'true_stim', 'rank_stim', 'true_resp', 'rank_resp']].head(5)
# Out:
#   subj condition  true_stim  rank_stim  true_resp  rank_resp
# 0    9  baseline      -0.18       22.5      0.064       61.5
# 1    9  baseline      -0.26       14.5     -0.100        8.0
# 2    9  baseline       0.34       74.5      0.136       75.5
# 3    9  baseline      -0.10       30.5     -0.136        5.0
# 4    9  baseline      -0.22       18.5      0.056       60.0

# %%
# error trials
df_subjs['invalid'] = df_subjs['trials.slider_resp.rt'].isna()
df_subjs['incomplete'] = df_subjs['trials.submit_resp.keys'].isna()
df_subjs['incorrect'] = (df_subjs['correct']==0) & ~df_subjs['invalid'] & ~df_subjs['incomplete']

print(f"invalid: {df_subjs['invalid'].mean()*100:.1f}%")
print(f"incomplete: {df_subjs['incomplete'].mean()*100:.1f}%")
print(f"incorrect: {df_subjs['incorrect'].mean()*100:.1f}%")
df_subjs[['correct', 'invalid', 'incomplete', 'incorrect']].head(5)
# Out:
# invalid: 1.8%
# incomplete: 1.7%
# incorrect: 17.2%
#    correct  invalid  incomplete  incorrect
# 0      0.0    False       False       True
# 1      1.0    False       False      False
# 2      0.0     True       False      False
# 3      1.0    False       False      False
# 4      0.0    False       False       True

# %% [markdown]
# ### timing checks

# %%
# create column for each phases's duration
expt_phases = ['baseline', 'stim', 'delay', 'task', 'anticipation', 'feedback']
for phase in expt_phases:
    df_subjs[f'{phase}_dur'] = df_subjs[f'{phase}.stopped'] - df_subjs[f'{phase}.started']

# sid, check if these are needed replacements
df_subjs['stim_dur'] = df_subjs['stim.stopped'] - df_subjs['target_stim.started']
df_subjs['feedback_dur'] = df_subjs['feedback.stopped'] - df_subjs['no_resp_text.started']

fig, axs = plt.subplots(2, 3, figsize=(15, 4))
axs, ax = axs.flatten(), 0

for expt_phase in expt_phases:

    sns.histplot(df_subjs[f'{expt_phase}_dur'], bins=20, kde=True, ax=axs[ax])
    axs[ax].set(title=expt_phase, xlabel='', ylabel='Count')
    ax += 1

plt.suptitle(f'Task Durations', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### outcome checks and save

# %%
# trial_key = design index (identical trial set across subjects); trial_chronological_idx = order actually played (0-239 per subj)
# blocks and trials-within-block were shuffled at presentation, so the two differ, and chronology differs across subjects
# chronology = run, then block slot within run (blocks.thisN), then trial slot within block (trials.thisN) -- NOT blockN
df_subjs['trial_chronological_idx'] = df_subjs.sort_values(['subj', 'run', 'blocks.thisN', 'trials.thisN']).groupby('subj').cumcount()

# sorted by trial_key for viewing; neur3 re-sorts by trial_chronological_idx to pair with neural triggers
df_subjs = df_subjs.sort_values(by=['subj', 'trial_key']).reset_index(drop=True)

print(df_subjs['subj'].value_counts(), '\n')
print(df_subjs['outcome'].value_counts(), '\n')
print(df_subjs['correct'].value_counts(), '\n')

# tag each patient with data eligibility (LFP only / behavior only / neuronal) from clinical records; pilots stay NaN
patient_docs = pd.read_csv('../../data/patient_documentation.csv')[['subj', 'notes']].rename(columns={'notes': 'eligibility'})
patient_docs['subj'] = (patient_docs['subj'] - 202500).astype(float)
df_subjs = df_subjs.merge(patient_docs, on='subj', how='left')
assert df_subjs[df_subjs['subj'] > 2]['eligibility'].notna().all()

df_subjs.to_csv('../../data/psychopy/all_beh_trials_df.csv', index=False)
# Out:
# subj
# 1.1       240
# 1.11      240
# 1.111     240
# 1.1111    240
# 9         240
# 11        240
# 12        240
# 18        240
# 21        240
# 22        240
# Name: count, dtype: int64
#
# outcome
#  1.0    951
#  3.0    571
#  5.0    387
# -1.0    242
# -3.0    160
# -5.0     89
# Name: count, dtype: int64
#
# correct
# 1.0    1909
# 0.0     491
# Name: count, dtype: int64
