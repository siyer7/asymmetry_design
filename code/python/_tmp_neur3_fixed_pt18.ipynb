# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns, glob, os
from utils import plot_style, norm01; plot_style('notebook');
import scipy.stats as stats, scipy.io as sio
from scipy.ndimage import gaussian_filter1d
from neo.io import BlackrockIO

# %% [markdown]
# ## Logical flow
# * Load neural_df (neurID, spikes, region, coords), beh_df (psychopy; stim and behavior), trigger_df (times for epochs and trials)
# * Extract spikes and FRs for each neurons, trial, epoch, subject
# * Visualize spikes and FRs
#     * raster+PSTH across 1st & 2nd halves of every trial
#     * raster+PSTH across stim_epoch, colored by context (orangered/grey/deepskyblue)
#     * raster+PSTH across stim_epoch, 1 subplot per context, all subplots colored by stimulus quartiles
#         * This means that there will be just 3 lines for contexts C1 & C3 because of stimulus sampling, but 4 lines for C2
#     * (Can leave commented): line plot of stim vs FR during stim_epoch
#         * Bin by counts, i.e., pool pairs of proximal undersampled stimuli. Maintain the print statement that verifies stim count per bucket.
#     * Heatmap of stim vs FR during stim_epoch across all neurons; subplotted per context
#         * Positional bins, like for raster/PSTH.
#         * Sort by region; labels to appear as ‘HPCx… AMYx… OFCx.. ACCx’. Currently no amygdala neurons exist fyi. Also want to sort by peak firing stim. Top neurs: maxFR at lowest stims.
# * Saves spikes (trials, neurs), FRs (trials, neurs, bins), and bins (bins,)

# %%
patient = 18; conds = ['curv_comp','baseline','flat_comp']
cntxts = ['C1','C2','C3']; thresholds = [-.2, 0, .2]; cntxt_colors= ['orangered', 'gray', 'deepskyblue']
normFR = False

# %% [markdown]
# ### 1. df_neurs

# %%
df_neurs = pd.read_parquet(f'/tmp/claude-1000/-home-nuttidalab-Documents-asymmetry-design/499e298e-0ce8-4dc5-9e52-98907a6405b6/scratchpad/fixed_outputs/processed_data/2025{patient}/df_neurs.parquet'); n_neurs = len(df_neurs)
eg_spikes = df_neurs['spikes'].iloc[0]; print(f'last 5 spikes (s): {eg_spikes[-5:]}\nlast 5 spikes (min): {eg_spikes[-5:] / 60}')
df_neurs
# Out:
# last 5 spikes (s): [1733.50833333 1733.69243333 1733.75293333 1734.59233333 1736.31      ]
# last 5 spikes (min): [28.89180556 28.89487389 28.89588222 28.90987222 28.9385    ]
#     patient  chanID     unitID  \
# 0        21     216       5338
# 1        21     217       1148
# 2        21     218       3804
# 3        21     218       3845
# 4        21     218  3887/3888
# 5        21     219       1329
# 6        21     219       1709
# 7        21     220       2305
# 8        21     220       2374
# 9        21     222        878
# 10       21     223       2492
# 11       21     223       2489
# 12       21     224       3097
# 13       21     224       3117
#
#                                                spikes  num_spikes         FR  \
# 0   [2.5876333333333337, 2.6418, 2.674966666666667...        7409   4.273464
# 1   [34.2711, 34.276633333333336, 34.3298, 36.1802...        1067   0.644605
# 2   [309.8436333333334, 317.89003333333335, 448.75...        1564   1.069608
# ...

# %% [markdown]
# ### 2. df_trigs
# note to work with relative instead of absolute time

# %%
# load
nev_file = glob.glob(f'../../data/2025{patient}/raw/*.nev')[0]; io = BlackrockIO(nev_file)
seg = io.read_block(lazy=False).segments[0]; dig_ev = [ev for ev in seg.events if "digital" in ev.name.lower()][0]

code_map = {10:"block started",20:"baseline started",30:"stim started",40:"delay started",50:"task started",51:"marker moved",52:"left pressed",53:"left released",54:"right pressed",55:"right released",56:"response submitted",60:"anticipation started",70:"feedback started",80:"block ended"}

# create df
df_trigs_raw = pd.DataFrame({"trigger_code": dig_ev.labels.astype(int),"time": dig_ev.times.magnitude}); df_trigs_raw["event"] = df_trigs_raw["trigger_code"].map(code_map)

# align times relative to block1 start
block1_start_idx = df_trigs_raw.index[df_trigs_raw["trigger_code"] == 10][0]; df_trigs_raw["rel_time"] = df_trigs_raw["time"] - df_trigs_raw.loc[block1_start_idx, "time"] # align times relative to block1 start

# drop triggers before block1 start; drop abs time
df_trigs = df_trigs_raw[block1_start_idx:]; df_trigs = df_trigs.drop(columns=['time']).reset_index(drop=True)

print(df_trigs['event'].value_counts(), end='\n\n'); print('Last 10 times in mins: ' + str(df_trigs['rel_time'][-10:].values / 60), end='\n\n')
df_trigs
# Out:
# event
# baseline started        240
# stim started            240
# delay started           240
# task started            240
# anticipation started    240
# feedback started        240
# marker moved            234
# response submitted      228
# left pressed            138
# left released           135
# right pressed           130
# right released          130
# block started             6
# block ended               6
# Name: count, dtype: int64
#
# Last 10 times in mins: [27.91275727 27.92942838 27.94750339 27.96414617 27.98888339 28.03776007
#  28.03776285 28.03888896 28.04303563 28.05980396]
#       trigger_code                 event     rel_time
# 0               10         block started     0.000000
# 1               20      baseline started    25.235138
# 2               30          stim started    26.319604
# 3               40         delay started    27.321305
# 4               50          task started    28.606505
# ...            ...                   ...          ...
# ...

# %% [markdown]
# ### 3. df_psychopy

# %%
df_psychopy_all = pd.read_csv('../../data/psychopy/all_subjs.csv'); print(f"All psychopy subjects: {df_psychopy_all['subj'].unique()}")
patients = df_psychopy_all['subj'].unique(); patients = patients[patients > 11]; print(patients)
# csv row order is scrambled (unstable sort in beh1); sort chronologically so row i = i-th trigger trial
df_pt_psychopy = df_psychopy_all.loc[df_psychopy_all['subj'] == patient].sort_values(['run', 'blocks.thisN', 'trials.thisN']).reset_index(drop=True)
df_pt_psychopy
# Out:
# All psychopy subjects: [ 1.1     1.11    1.111   1.1111  9.     11.     12.     18.     21.
#  22.    ]
# [12. 18. 21. 22.]
#      thisN  thisTrialN  thisRepN  blockN  run  condition  trial_key  \
# 0     39.0        39.0       0.0     6.0  2.0  flat_comp      201.0
# 1      1.0         1.0       0.0     1.0  1.0   baseline       27.0
# 2     38.0        38.0       0.0     6.0  2.0  flat_comp      208.0
# 3      6.0         6.0       0.0     3.0  1.0  flat_comp      113.0
# 4      5.0         5.0       0.0     3.0  1.0  flat_comp      114.0
# ..     ...         ...       ...     ...  ...        ...        ...
# 235   34.0        34.0       0.0     5.0  2.0  curv_comp      178.0
# 236   33.0        33.0       0.0     5.0  2.0  curv_comp      175.0
# 237   32.0        32.0       0.0     5.0  2.0  curv_comp      167.0
# 238    4.0         4.0       0.0     4.0  2.0   baseline      123.0
# 239   38.0        38.0       0.0     3.0  1.0  flat_comp      103.0
#
# ...

# %% [markdown]
# ### variables

# %%
size, dt = .02, .01 # smoothing params

# set epoch prestarts and durations (xlims)
epochs = ['baseline', 'stim', 'delay', 'response', 'feedback']; epoch_prestarts, epoch_durs = {}, {}

for epoch in epochs:

    # where to start x-axis
    if epoch == 'baseline': epoch_prestarts[epoch] = -0
    elif epoch == 'response': epoch_prestarts[epoch] = -1 # 1s before response submitted
    else: epoch_prestarts[epoch] = -.25

    # plot duration
    if epoch == 'delay': epoch_durs[epoch] = 1.5
    elif epoch == 'response': epoch_durs[epoch] = 0 # 0s after response submitted
    else: epoch_durs[epoch] = 1

print(f'prestarts (xlim start): {epoch_prestarts}\ndurations: (xlim end): {epoch_durs}\n')

# trial half prestarts and durations
trial_halves = ['pre-choice, stim-anchored', 'post-choice, outcome-anchored']
trial_half_prestarts = {'pre-choice, stim-anchored': -.25, 'post-choice, outcome-anchored': -1.25}
trial_half_durs      = {'pre-choice, stim-anchored': 3.5,  'post-choice, outcome-anchored': 1.0}

print(f'trial half prestarts: {trial_half_prestarts}\ntrial half durations: {trial_half_durs}')
# Out:
# prestarts (xlim start): {'baseline': 0, 'stim': -0.25, 'delay': -0.25, 'response': -1, 'feedback': -0.25}
# durations: (xlim end): {'baseline': 1, 'stim': 1, 'delay': 1.5, 'response': 0, 'feedback': 1}
#
# trial half prestarts: {'pre-choice, stim-anchored': -0.25, 'post-choice, outcome-anchored': -1.25}
# trial half durations: {'pre-choice, stim-anchored': 3.5, 'post-choice, outcome-anchored': 1.0}

# %% [markdown]
# ### helpers

# %%
def get_normed_FRs(FRs, base_FRs):
    return FRs - base_FRs.mean(axis=(0, 2), keepdims=True) # trial-avged baseline, (neurons, 1)
    # return FRs - base_FRs.mean(axis=2, keepdims=True) # baseline FR per trial, (trials, neurons, 1)
    # return FRs # no norming

def get_epoch_spikes_and_FRs(df_trigs, df_neurs, epoch, size=size, dt=dt):
    ''' for each trial and neuron, get spike times and smoothed FRs (Hz) in epoch window
        df_trigs: trig times, df_neurs: spike times per neur '''

    epoch_prestart, epoch_dur = epoch_prestarts[epoch], epoch_durs[epoch]
    bin_edges = np.arange(epoch_prestart, epoch_dur + dt, dt); bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2; n_bins = len(bin_edges) - 1

    # get epoch start indices & times
    if epoch != 'response': epoch_start_rows = df_trigs[df_trigs['event'] == f'{epoch} started'].index
    # using anticipation started instead of response submitted bc sometimes they dont respond
    else: epoch_start_rows = df_trigs[df_trigs['event'] == 'anticipation started'].index
    epoch_starts = df_trigs.loc[epoch_start_rows, 'rel_time'].values; n_trials = len(epoch_starts)

    trial_neur_spikes, trial_neur_FRs = np.empty((n_trials, len(df_neurs)), dtype=object), np.zeros((n_trials, len(df_neurs), n_bins))

    for trial_idx in range(n_trials):
        for neur_idx, (_, neur_row) in enumerate(df_neurs.iterrows()):

            trial_epoch_spikes = neur_row['spikes'][(neur_row['spikes'] >= epoch_starts[trial_idx] + epoch_prestart) &
                                                    (neur_row['spikes'] <= epoch_starts[trial_idx] + epoch_dur)]
            trial_epoch_spikes = trial_epoch_spikes - epoch_starts[trial_idx] # align

            # bin and smooth
            counts, _ = np.histogram(trial_epoch_spikes, bins=bin_edges)
            smooth_spike_train = gaussian_filter1d(counts.astype(float), sigma=size/dt, mode='reflect', truncate=3.0)
            smooth_spike_train = smooth_spike_train / dt  # instantaneous FR (Hz): spikes/bin ÷ s/bin

            trial_neur_spikes[trial_idx, neur_idx], trial_neur_FRs[trial_idx, neur_idx, :] = trial_epoch_spikes, smooth_spike_train

    return trial_neur_spikes, trial_neur_FRs, bin_centers

base_spikes, base_FRs, bin_centers = get_epoch_spikes_and_FRs(df_trigs, df_neurs, epoch)
n_trials, n_neurs = base_spikes.shape[:2]

# %% [markdown]
# ### visualization 1

# %% [markdown]
# note that the visualization become quite poor after updating plot settings at the top of the notebook.

# %%
for _ in range(3):

    rand_trial_idx, rand_neur_idx = np.random.randint(0, n_trials), np.random.randint(0, n_neurs)

    fig, ax = plt.subplots(2, 1, figsize=(4,2), sharex=True)

    spikes = base_spikes[rand_trial_idx, rand_neur_idx]
    ax[0].set(title=f"Trial {rand_trial_idx}, Neuron {rand_neur_idx}, Baseline", ylabel="spikes", yticks=[])
    ax[0].tick_params(axis='both', bottom=False, labelbottom=False)
    ax[0].eventplot(spikes, colors='black', lineoffsets=0, linelengths=0.8)

    fr = base_FRs[rand_trial_idx, rand_neur_idx]
    ax[1].set(xlabel="time (s)", xlim=(0, 1), ylabel="FR (Hz)")
    ax[1].plot(bin_centers, fr)

    plt.tight_layout()
    plt.show()

# %%
epoch = 'stim'; spikes, FRs, bin_centers = get_epoch_spikes_and_FRs(df_trigs, df_neurs, epoch)

fig, ax = plt.subplots(1, 1, figsize=(4,3))
neur_idx = 1; neur_region = df_neurs.iloc[neur_idx]['region']
ax.set(title = f'Example {neur_region[2:-1]} neuron', ylabel='Trials', xlabel='Time from stimulus onset (s)', xticks=np.arange(-.25, 1.01, .25), xlim=(-.25,1), ylim=(0,240), yticks=np.arange(40, 241, 40))
ax.eventplot(spikes[:, neur_idx], colors='black', linelengths=0.8)
ax.axvline(0, color='red', linestyle='--')

plt.tight_layout(); plt.show()

# %% [markdown]
# ### visualization 2

# %%
def get_trial_half_spikes_and_FRs(df_trigs, df_neurs, trial_half, size=size, dt=dt):
    ''' spikes + smoothed FRs (Hz) for all trials, aligned to a trial half's onset
        pre-choice aligned to stim onset, post-choice aligned to outcome (anticipation) onset '''

    prestart, dur = trial_half_prestarts[trial_half], trial_half_durs[trial_half]
    bin_edges = np.arange(prestart, dur + dt, dt); bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2; n_bins = len(bin_edges) - 1

    anchor_event = 'stim started' if trial_half == trial_halves[0] else 'anticipation started'
    anchor_times = df_trigs.loc[df_trigs['event'] == anchor_event, 'rel_time'].values

    trial_neur_spikes, trial_neur_FRs = np.empty((len(anchor_times), len(df_neurs)), dtype=object), np.zeros((len(anchor_times), len(df_neurs), n_bins))
    for trial_idx, t0 in enumerate(anchor_times):
        for neur_idx, (_, neur_row) in enumerate(df_neurs.iterrows()):
            s = neur_row['spikes']
            s = s[(s >= t0 + prestart) & (s <= t0 + dur)] - t0
            counts, _ = np.histogram(s, bins=bin_edges)
            smooth = gaussian_filter1d(counts.astype(float), sigma=size/dt, mode='reflect', truncate=3.0) / dt
            trial_neur_spikes[trial_idx, neur_idx] = s
            trial_neur_FRs[trial_idx, neur_idx, :] = smooth

    return trial_neur_spikes, trial_neur_FRs, bin_centers

trial_half_data = {th: get_trial_half_spikes_and_FRs(df_trigs, df_neurs, th) for th in trial_halves}

# epoch-name annotations placed below the x-axis, per trial half column (x position, label)
half_epoch_labels = [
    [(0.5, 'Stim'), (1.75, 'Delay'), (3.0, 'Resp')],       # pre-choice, stim-anchored
    [(-.75, 'Resp'), (.5, 'Outcome')],                     # post-choice, outcome-anchored
]

fig, axs = plt.subplots(n_neurs, 2, figsize=(11, n_neurs * 3))
if n_neurs == 1: axs = axs[np.newaxis, :]

for neur_id in range(n_neurs):
    for col, trial_half in enumerate(trial_halves):

        half_spikes, half_FRs, half_bin_centers = trial_half_data[trial_half]
        n_trials_half = half_spikes.shape[0]
        if normFR: half_FRs, ylab = get_normed_FRs(half_FRs, base_FRs), 'norm. FR (Hz)'
        else: half_FRs, ylab = half_FRs.copy(), 'FR (Hz)'

        # placeholder to be replaced with 2 stacked axes
        ss = axs[neur_id, col].get_subplotspec(); axs[neur_id, col].remove()
        gs = ss.subgridspec(2, 1, height_ratios=[1, 1], hspace=0)
        ax_raster = fig.add_subplot(gs[0]); ax_psth = fig.add_subplot(gs[1], sharex=ax_raster)

        ax_raster.eventplot(half_spikes[:, neur_id], colors='k', lineoffsets=np.arange(n_trials_half), linelengths=5.0, linewidths=1.0)
        ax_raster.tick_params(axis='x', which='both', bottom=False, labelbottom=False)
        align_lab = 'stim onset' if col == 0 else 'outcome onset'
        ax_raster.set(title=f"{df_neurs['region'].iloc[neur_id]}, Neuron {neur_id} ({align_lab})")

        data = half_FRs[:, neur_id, :]
        mu, sderr = data.mean(axis=0), data.std(axis=0, ddof=1) / np.sqrt(data.shape[0])
        ax_psth.plot(half_bin_centers, mu, color='k', linewidth=1)
        ax_psth.fill_between(half_bin_centers, mu - sderr, mu + sderr, color='0.7', alpha=0.5, linewidth=0)

        # trial half onset/boundary markers
        for ax in (ax_raster, ax_psth): ax.axvline(0, color='k', linestyle='--', alpha=.5)
        if col == 0:
            for ax in (ax_raster, ax_psth):
                ax.axvline(1, color='k', linestyle='--', alpha=.5)    # end of delay
                ax.axvline(2.5, color='k', linestyle='--', alpha=.5)  # end of response
        else:
            for ax in (ax_raster, ax_psth): ax.axvline(-.25, color='k', linestyle='--', alpha=.5)
            ax_psth.set_xticks(np.arange(-1.0, 1.01, .5))  # reduce tick frequency (was every .25)

        ax_psth.set(xlim=(half_bin_centers[0], half_bin_centers[-1]), ylabel=ylab)
        ax_psth.set_xlabel('Time (s)', labelpad=20)  # push below the epoch-name row so they don't collide

        # epoch-name text between the numeric tick labels and the x-axis label (added, not replacing ticks)
        for x, label in half_epoch_labels[col]:
            ax_psth.text(x, -.25, label, transform=ax_psth.get_xaxis_transform(), ha='center', va='top', fontsize=10)

plt.suptitle(f'Patient {patient}, trial halves', y=1.0, fontsize=14); plt.tight_layout()
plt.savefig(f'/tmp/claude-1000/-home-nuttidalab-Documents-asymmetry-design/499e298e-0ce8-4dc5-9e52-98907a6405b6/scratchpad/fixed_outputs/figs/single-units/pt{patient}_trial_halves.png'); plt.show()

# %%
epoch = ['baseline', 'stim', 'delay', 'response', 'feedback'][1]
ymin, ymax = -2, 2 # optional

spikes, FRs, bin_centers = get_epoch_spikes_and_FRs(df_trigs, df_neurs, epoch, size, dt)
n_trials, n_neurs = FRs.shape[0], FRs.shape[1]
if epoch!='baseline': FRs, yaxis_lab = get_normed_FRs(FRs, base_FRs), 'norm. '
else: FRs, yaxis_lab = FRs.copy(), ''

# color each trial by its context (orangered/gray/deepskyblue)
trial_colors = df_pt_psychopy['condition'].map(dict(zip(conds, cntxt_colors))).values

n_cols = 3; n_rows = int(np.ceil(n_neurs / n_cols))
fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols*4, n_rows*3)); axs, ax = axs.flatten(), 0
first_psth_ax = None

for neur_id in range(n_neurs):

    if ax >= len(axs): break

    # placeholder to be replaced with 2 stacked axes
    ss = axs[ax].get_subplotspec(); axs[ax].remove()
    gs = ss.subgridspec(2, 1, height_ratios=[1, 1], hspace=0)
    ax_raster = fig.add_subplot(gs[0]); ax_psth = fig.add_subplot(gs[1], sharex=ax_raster)
    if first_psth_ax is None: first_psth_ax = ax_psth

    ax_raster.eventplot(spikes[:, neur_id], colors=trial_colors, lineoffsets=np.arange(n_trials), linelengths=5.0, linewidths=1.0)
    ax_raster.tick_params(axis='x', which='both', bottom=False, labelbottom=False)
    ax_raster.axvline(0, color='red', linestyle='--')
    ax_raster.set(title=f"{df_neurs['region'].iloc[neur_id]}, Neuron {neur_id}")

    # psth — mean ± sem per context
    for cond, cntxt, cntxt_color in zip(conds, cntxts, cntxt_colors):
        cond_ids = df_pt_psychopy.index[df_pt_psychopy['condition'] == cond]
        data = FRs[cond_ids, neur_id, :]
        mu, sderr = data.mean(axis=0), data.std(axis=0, ddof=1) / np.sqrt(data.shape[0])
        ax_psth.plot(bin_centers, mu, color=cntxt_color, label=cntxt, linewidth=1)
        ax_psth.fill_between(bin_centers, mu - sderr, mu + sderr, color=cntxt_color, alpha=.2, linewidth=0)
    ax_psth.axvline(0, color='red', linestyle='--')
    ax_psth.set(xlim=(bin_centers[0], bin_centers[-1]),ylabel=f"{yaxis_lab}FR (Hz)", xlabel=f"Time (s)")#,ylim=(ymin, ymax))

    ax += 1

first_psth_ax.legend(loc='lower right', fontsize=7)
plt.suptitle(f'Patient {patient}, {epoch} epoch', y=1.0, fontsize=14); plt.tight_layout()
plt.savefig(f'/tmp/claude-1000/-home-nuttidalab-Documents-asymmetry-design/499e298e-0ce8-4dc5-9e52-98907a6405b6/scratchpad/fixed_outputs/figs/single-units/pt{patient}_{epoch}_epoch.png'); plt.show()

# %% [markdown]
# ### Bin by position

# %%
norm = False; n_contrast_bins = 4
spikes, FRs, bin_centers = get_epoch_spikes_and_FRs(df_trigs, df_neurs, epoch)
if norm: FRs = get_normed_FRs(FRs, base_FRs); yaxis_lab = 'norm. '
else: yaxis_lab = ''
n_trials, n_neurs = FRs.shape[0], FRs.shape[1]

shared_contrast_edges = np.linspace(-.4, .4, n_contrast_bins + 1)  # fixed, equal-width edges shared across conditions -> a given true_stim always lands in the same bucket

for i, cond in enumerate(conds):
    cond_psychopy_df = df_pt_psychopy[df_pt_psychopy['condition'] == cond]

    stim_bins   = pd.cut(cond_psychopy_df['true_stim'], bins=shared_contrast_edges)
    cont_trials = [cond_psychopy_df.index[stim_bins == cat] for cat in stim_bins.cat.categories]
    cont_labels = [f'{cat.left:.2f} to {cat.right:.2f}' for cat in stim_bins.cat.categories]
    colors      = plt.cm.coolwarm(np.linspace(0, 1, n_contrast_bins))

    n_cols = 3; n_rows = int(np.ceil(n_neurs / n_cols))
    fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols*4, n_rows*3)); axs, ax = axs.flatten(), 0
    first_psth_ax = None

    for neur_id in range(n_neurs):

        if ax >= len(axs): break

        # placeholder to be replaced with 2 stacked axes
        ss = axs[ax].get_subplotspec(); axs[ax].remove()
        gs = ss.subgridspec(2, 1, height_ratios=[1, 1])
        ax_raster = fig.add_subplot(gs[0]); ax_psth = fig.add_subplot(gs[1], sharex=ax_raster)
        if first_psth_ax is None: first_psth_ax = ax_psth

        # raster — trials sorted and colored by contrast group; one scatter call per group (not per trial)
        trial_counter = 0
        for grp, grp_color in list(zip(cont_trials, colors))[::-1]:
            if len(grp) == 0: continue  # bucket empty for this condition -> skip
            xs, ys = [], []
            for trial_idx in grp:
                st = spikes[trial_idx, neur_id]
                xs.append(st); ys.append(np.full_like(st, trial_counter))
                trial_counter += 1
            ax_raster.scatter(np.concatenate(xs), np.concatenate(ys), s=3, color=grp_color, alpha=.7)
        ax_raster.tick_params(axis='x', which='both', bottom=False, labelbottom=False)
        ax_raster.axvline(0, color='black', linestyle='--')
        ax_raster.set(title=f"{df_neurs['region'].iloc[neur_id]}, Neuron {neur_id}", ylabel='Sorted trials')

        # psth — mean ± sem per group
        for grp, grp_label, grp_color in zip(cont_trials, cont_labels, colors):
            if len(grp) == 0: continue  # bucket empty for this condition -> skip
            data = FRs[list(grp), neur_id, :]
            mu = data.mean(axis=0)
            sderr = data.std(axis=0, ddof=1) / np.sqrt(data.shape[0])
            ax_psth.plot(bin_centers, mu, color=grp_color, alpha=.9, label=grp_label)
            ax_psth.fill_between(bin_centers, mu - sderr, mu + sderr, color=grp_color, alpha=.2, linewidth=0)
        ax_psth.axvline(0, color='black', linestyle='--')
        ax_psth.set(xlim=(bin_centers[0], bin_centers[-1]), xticks=np.linspace(-.25,1,6), ylabel='FR (Hz)', xlabel='Time (s)')

        ax += 1

    first_psth_ax.legend(loc='lower right', fontsize=7)
    plt.suptitle(f'Shape modulation, pt{patient}, Context {cntxts[i]}, {epoch} epoch', y=1.0, fontsize=14); plt.tight_layout()
    plt.savefig(f'/tmp/claude-1000/-home-nuttidalab-Documents-asymmetry-design/499e298e-0ce8-4dc5-9e52-98907a6405b6/scratchpad/fixed_outputs/figs/single-units/{cntxts[i]}/pt{patient}_{epoch}_epoch_tuning_psth.png'); plt.show()

# %% [markdown]
# ### Bin by count

# %%
spikes, FRs, bin_centers = get_epoch_spikes_and_FRs(df_trigs, df_neurs, epoch)
if norm: FRs = get_normed_FRs(FRs, base_FRs); ylab = 'norm. '
else: ylab = ''
trial_mean_FR = FRs.mean(axis=2)
n_trials, n_neurs = trial_mean_FR.shape

def equal_count_edges(shape_positions, target_n=8):
    ''' bin edges that pool adjacent, actually-observed stim positions (0-count positions are
        skipped since np.unique never returns them) until each bucket holds >= target_n trials '''
    vals, counts = np.unique(shape_positions, return_counts=True)
    step = np.diff(vals).min()
    edges, running = [vals[0] - step / 2], 0
    for v, c in zip(vals, counts):
        running += c
        if running >= target_n:
            edges.append(v + step / 2)
            running = 0
    return np.array(edges)

for i, cond in enumerate(conds):
    cond_ids        = df_pt_psychopy.index[df_pt_psychopy['condition'] == cond]
    shape_positions = df_pt_psychopy.loc[cond_ids, 'true_stim']

    cond_edges   = equal_count_edges(shape_positions)
    shape_bins   = pd.cut(shape_positions, bins=cond_edges)
    shape_trials = [shape_bins.index[shape_bins == cat] for cat in shape_bins.cat.categories]
    bucket_x     = np.array([cat.mid for cat in shape_bins.cat.categories])
    trial_x      = bucket_x[shape_bins.cat.codes.values]

    print(f'--- {cntxts[i]} ({cond}), n_trials={len(cond_ids)} ---')
    for cat, trials in zip(shape_bins.cat.categories, shape_trials): print(f'  {cat.mid:6.2f} ({cat.left:.2f} to {cat.right:.2f}): n={len(trials)}')
    print()

#     n_cols = 3; n_rows = int(np.ceil(n_neurs / n_cols))
#     fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols*4, n_rows*3)); axs, ax = axs.flatten(), 0

#     for neur_id in range(n_neurs):

#         if ax >= len(axs): break

#         cond_FR = trial_mean_FR[cond_ids, neur_id]
#         axs[ax].scatter(trial_x + np.random.normal(0, 0.005, size=len(cond_ids)), cond_FR, s=8, color='0.7', alpha=.6) # raw trials

#         mu  = [trial_mean_FR[trials, neur_id].mean() if len(trials) else np.nan for trials in shape_trials]  # empty bin -> gap, not a fake 0
#         sem = [trial_mean_FR[trials, neur_id].std(ddof=1) / np.sqrt(len(trials)) if len(trials) > 1 else np.nan for trials in shape_trials]
#         axs[ax].errorbar(bucket_x, mu, yerr=sem, color=cntxt_colors[i], marker='o', markersize=4, linewidth=1.5)

#         axs[ax].axvline(thresholds[i], color=cntxt_colors[i], linestyle='--')
#         ymin, ymax = np.percentile(cond_FR, [0, 95])
#         axs[ax].set(title=f"{df_neurs['region'].iloc[neur_id]}, Neuron {neur_id}", xlabel='Shape', ylabel=f'{ylab}FR (Hz)', ylim=(-.5, ymax),xlim=(-.4, .4), xticks=np.linspace(-.4, .4, 5))
#         ax += 1

#     for ax_idx in range(n_neurs, len(axs)):    axs[ax_idx].axis('off')

#     plt.suptitle(f'Shape Tuning: pt{patient}, {epoch} epoch, {cntxts[i]} context', y=1.0, fontsize=14); plt.tight_layout()
#     plt.savefig(f'/tmp/claude-1000/-home-nuttidalab-Documents-asymmetry-design/499e298e-0ce8-4dc5-9e52-98907a6405b6/scratchpad/fixed_outputs/figs/single-units/{cntxts[i]}/pt{patient}_{epoch}_epoch_tuning_lineplot.png'); plt.show()
# Out:
# --- C1 (curv_comp), n_trials=80 ---
#    -0.38 (-0.40 to -0.36): n=8
#    -0.34 (-0.36 to -0.32): n=8
#    -0.30 (-0.32 to -0.28): n=8
#    -0.26 (-0.28 to -0.24): n=8
#    -0.22 (-0.24 to -0.20): n=8
#    -0.16 (-0.20 to -0.12): n=8
#    -0.08 (-0.12 to -0.04): n=8
#     0.00 (-0.04 to 0.04): n=8
#     0.08 (0.04 to 0.12): n=8
#     0.16 (0.12 to 0.20): n=8
#
# --- C2 (baseline), n_trials=80 ---
#    -0.36 (-0.40 to -0.32): n=8
#    -0.28 (-0.32 to -0.24): n=8
#    -0.20 (-0.24 to -0.16): n=8
#    -0.12 (-0.16 to -0.08): n=8
#    -0.04 (-0.08 to -0.00): n=8
#     0.04 (-0.00 to 0.08): n=8
#     0.12 (0.08 to 0.16): n=8
#     0.20 (0.16 to 0.24): n=8
#     0.28 (0.24 to 0.32): n=8
#     0.36 (0.32 to 0.40): n=8
#
# --- C3 (flat_comp), n_trials=80 ---
#    -0.16 (-0.20 to -0.12): n=8
#    -0.08 (-0.12 to -0.04): n=8
#     0.00 (-0.04 to 0.04): n=8
#     0.08 (0.04 to 0.12): n=8
#     0.16 (0.12 to 0.20): n=8
#     0.22 (0.20 to 0.24): n=8
#     0.26 (0.24 to 0.28): n=8
# ...

# %% [markdown]
# ### Bin by position pairs

# %%
n_buckets = 10
cond_thresholds = dict(zip(conds, [-.2, 0, .2]))  # curv_comp, baseline, flat_comp boundaries
shared_edges = np.linspace(-.4, .4, n_buckets + 1)  # same bins for every panel, not per-condition

cmap = plt.cm.RdBu_r.copy()
cmap.set_bad('black')  # bins with no trials for this condition shown black instead of blending in

# region per neuron for sorting/labels: 'mRAHIP5' -> 'AHIP' -> 'HPC'; bare channel numbers -> 'unk'
region_order = ['HPC', 'AMY', 'OFC', 'ACC', 'unk']
def parse_region(raw_region):
    if raw_region.isdigit(): return 'unk'
    region = raw_region[2:-1]; return 'HPC' if 'HIP' in region else region
neur_regions = np.array([parse_region(raw) for raw in df_neurs['region']])
region_rank = np.array([region_order.index(region) for region in neur_regions])

fig, axs = plt.subplots(3, 1, figsize=(6, 12))

for i, cond in enumerate(conds):
    cond_trial_ids  = df_pt_psychopy.index[df_pt_psychopy['condition'] == cond]
    shape_positions = df_pt_psychopy.loc[cond_trial_ids, 'true_stim'].values
    X = trial_mean_FR[cond_trial_ids]
    Z = (X - X.mean(axis=0)) / X.std(axis=0)

    bins = pd.cut(shape_positions, bins=shared_edges)
    heat = np.array([Z[bins == cat].mean(axis=0) if (bins == cat).any() else np.full(X.shape[1], np.nan)
                      for cat in bins.categories]).T  # (n_neurs, n_buckets); empty bins -> NaN, shown black

    # sort rows region-major (HPC, AMY, OFC, ACC, unk), then by this context's peak-firing stim -> lowest-stim peaks on top
    peak_buckets = np.nanargmax(heat, axis=1)
    sort_idx = np.lexsort((peak_buckets, region_rank)); heat = heat[sort_idx]

    absmax = np.nanmax(np.abs(heat))
    im = axs[i].imshow(heat, aspect='auto', cmap=cmap, vmin=-absmax, vmax=absmax, extent=[shared_edges[0], shared_edges[-1], heat.shape[0], 0])
    axs[i].axvline(cond_thresholds[cond], color='k', linestyle='--', linewidth=1)
    axs[i].set(title=cntxts[i], xlabel='Shape position', ylabel='Neuron', xlim=(shared_edges[0], shared_edges[-1]),yticks=np.arange(n_neurs) + 0.5, yticklabels=[f'{neur_regions[neur_id]}{neur_id}' for neur_id in sort_idx])
    plt.colorbar(im, ax=axs[i], label='z-scored FR', shrink=0.8)

plt.suptitle(f'Shape tuning, patient {patient}, {epoch} epoch', y=1.0); plt.tight_layout()
plt.savefig(f'/tmp/claude-1000/-home-nuttidalab-Documents-asymmetry-design/499e298e-0ce8-4dc5-9e52-98907a6405b6/scratchpad/fixed_outputs/figs/single-units/pt{patient}_{epoch}_epoch_tuning_heatmap.png'); plt.show()

# %% [markdown]
# ### save patient df_trigs and epoch data (neur_df already saved in previous notebook)

# %%
processed_data_dir = f'/tmp/claude-1000/-home-nuttidalab-Documents-asymmetry-design/499e298e-0ce8-4dc5-9e52-98907a6405b6/scratchpad/fixed_outputs/processed_data/2025{patient}'; os.makedirs(processed_data_dir, exist_ok=True); print(f'\nsaving to {processed_data_dir}')

os.makedirs(f'{processed_data_dir}/matrices', exist_ok=True)

df_trigs.to_parquet(f'{processed_data_dir}/df_trigs.parquet'); print(f'df_trigs: ({len(df_trigs)} rows)')

for epoch in epochs:
    print(f'\n{epoch}:')
    ep_spikes, ep_FRs, ep_bin_centers = get_epoch_spikes_and_FRs(df_trigs, df_neurs, epoch)
    np.save(f'{processed_data_dir}/matrices/{epoch}_spikes.npy', ep_spikes, allow_pickle=True)
    np.save(f'{processed_data_dir}/matrices/{epoch}_FRs.npy', ep_FRs, allow_pickle=True)
    np.save(f'{processed_data_dir}/matrices/{epoch}_bin_centers.npy', ep_bin_centers, allow_pickle=True)
    print(f'spikes {ep_spikes.shape}, FRs {ep_FRs.shape}, bins {ep_bin_centers.shape}')
# Out:
# saving to ../../outputs/processed_data/202521
# df_trigs: (2449 rows)
#
# baseline:
# spikes (240, 14), FRs (240, 14, 100), bins (100,)
#
# stim:
# spikes (240, 14), FRs (240, 14, 125), bins (125,)
#
# delay:
# spikes (240, 14), FRs (240, 14, 175), bins (175,)
#
# response:
# spikes (240, 14), FRs (240, 14, 100), bins (100,)
#
# feedback:
# spikes (240, 14), FRs (240, 14, 125), bins (125,)

# %% [markdown]
# plot electrode location

# %%
# template = datasets.load_mni152_template()

# # grab most distal channels for each electrode
# # IDs were different for older recording system (pt12)
# if patient == 12: plot_chanIDs = [97, 105, 113]
# else: plot_chanIDs = [193, 202, 210]

# coords_list = []
# for ch in plot_chanIDs:
#     row = df_neurs[df_neurs['chanID'] == ch].iloc[0]   # first match
#     coords_list.append([row.x, row.y, row.z])

# coords = np.array(coords_list)

# coord_regions  = ['OFC', 'ACC', 'HIP']
# colors = {'OFC':'red', 'ACC':'cyan', 'HIP':'orange'}
# marker_size = 20
# # x = sagittal, y = coronal, z = axial

# # 1. axial
# # fix z (axial)
# axial_cut = 0
# coords_ax = coords.copy()
# coords_ax[:,2] = axial_cut
# disp1 = plotting.plot_anat(template, display_mode='z', cut_coords=[axial_cut],
#                            cmap='gray', black_bg=True, draw_cross=False, colorbar=False)
# for (x,y,z), name in zip(coords_ax, coord_regions):
#     disp1.add_markers([(x,y,z)], marker_size=marker_size, marker_color=colors[name])
    
# # 2. sagittal (x=0)
# sag1_cut = 0
# coords_sag1 = coords.copy()
# coords_sag1[:,0] = sag1_cut
# disp2 = plotting.plot_anat(template, display_mode='x', cut_coords=[sag1_cut],
#                            cmap='gray', black_bg=True, draw_cross=False, colorbar=False)
# for (x,y,z), name in zip(coords_sag1, coord_regions):
#     disp2.add_markers([(x,y,z)], marker_size=marker_size, marker_color=colors[name])

# # 3. coronal (y=30)
# cor_cut = 0
# coords_cor = coords.copy()
# coords_cor[:,1] = cor_cut
# disp4 = plotting.plot_anat(template, display_mode='y', cut_coords=[cor_cut],
#                            cmap='gray', black_bg=True, draw_cross=False, colorbar=False)
# for (x,y,z), name in zip(coords_cor, coord_regions):
#     disp4.add_markers([(x,y,z)], marker_size=marker_size, marker_color=colors[name])

# plotting.show()

# print(colors)

# %%
# # revived from arch/old_code_chunks.ipynb: per-neuron raster + PSTH split by trial half
# # pre-choice aligned to stim onset, post-choice aligned to outcome (anticipation) onset

# def get_trial_half_spikes_and_FRs(df_trigs, df_neurs, trial_half, contrast, size=size, dt=dt):
#     ''' spikes + smoothed FRs (Hz) aligned to a trial half's onset, plus trial groupings for a contrast '''

#     prestart, dur = trial_half_prestarts[trial_half], trial_half_durs[trial_half]
#     bin_edges = np.arange(prestart, dur + dt, dt); bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2; n_bins = len(bin_edges) - 1

#     # anchor: stim onset for pre-choice, outcome onset for post-choice
#     anchor_event = 'stim started' if trial_half == trial_halves[0] else 'anticipation started'
#     anchor_times = df_trigs.loc[df_trigs['event'] == anchor_event, 'rel_time'].values

#     trial_neur_spikes, trial_neur_FRs = np.empty((len(anchor_times), len(df_neurs)), dtype=object), np.zeros((len(anchor_times), len(df_neurs), n_bins))
#     for trial_idx, t0 in enumerate(anchor_times):
#         for neur_idx, (_, neur_row) in enumerate(df_neurs.iterrows()):
#             s = neur_row['spikes']
#             s = s[(s >= t0 + prestart) & (s <= t0 + dur)] - t0
#             counts, _ = np.histogram(s, bins=bin_edges)
#             smooth = gaussian_filter1d(counts.astype(float), sigma=size/dt, mode='reflect', truncate=3.0) / dt
#             trial_neur_spikes[trial_idx, neur_idx] = s
#             trial_neur_FRs[trial_idx, neur_idx, :] = smooth

#     # trial groupings — gain/loss uses signed distance from decision boundary
#     if contrast == 'class':
#         cont_trials = [df_pt_psychopy.index[df_pt_psychopy['stim_boundary_aligned'] < 0], df_pt_psychopy.index[df_pt_psychopy['stim_boundary_aligned'] > 0]]
#         cont_labels, colors = ['<thresh', '>thresh'], ['b', 'r']
#     elif contrast == 'outcome':
#         vals = [5, 3, 1, -1, -3, -5]
#         cont_trials = [df_pt_psychopy.index[df_pt_psychopy['outcome'] == v] for v in vals]
#         cont_labels, colors = [f'{v:+d} coins' for v in vals], plt.cm.coolwarm(np.linspace(1, 0, len(vals)))
#     else:
#         raise ValueError(f'Invalid contrast: {contrast}')

#     return trial_neur_spikes, trial_neur_FRs, bin_centers, cont_trials, cont_labels, colors


# neur_idx, contrast = 1, 'class'
# fig, axs = plt.subplots(2, 2, figsize=(11, 5), sharey='row', gridspec_kw={'width_ratios': [3.5, 2], 'height_ratios': [1, 1]})

# for col, trial_half in enumerate(trial_halves):
#     spikes, FRs, bin_centers, cont_trials, cont_labels, colors = get_trial_half_spikes_and_FRs(df_trigs, df_neurs, trial_half, contrast)
#     normed_FRs = get_normed_FRs(FRs, base_FRs)

#     trial_counter = 0
#     for grp, grp_color in list(zip(cont_trials, colors))[::-1]:
#         for trial_idx in grp:
#             st = spikes[trial_idx, neur_idx]
#             axs[0, col].scatter(st, np.full_like(st, trial_counter), s=3, color=grp_color, alpha=.7)
#             trial_counter += 1
#     axs[0, col].set(title='Aligned to stimulus onset' if col == 0 else 'Aligned to outcome onset')

#     # psth — mean ± sem per group
#     for grp, grp_label, grp_color in zip(cont_trials, cont_labels, colors):
#         data = normed_FRs[list(grp), neur_idx, :]
#         mu = data.mean(axis=0)
#         sderr = data.std(axis=0, ddof=1) / np.sqrt(data.shape[0]) if data.shape[0] > 1 else np.zeros_like(mu)
#         axs[1, col].plot(bin_centers, mu, color=grp_color, alpha=.9, label=grp_label)
#         axs[1, col].fill_between(bin_centers, mu - sderr, mu + sderr, color=grp_color, alpha=.2, linewidth=0)

#     # epoch onsets
#     for ax in axs[:, col]:    ax.axvline(0, color='k', linestyle='--', alpha=.5)
#     if col == 0:
#         for ax in axs[:, col]:
#             ax.axvline(1, color='k', linestyle='--', alpha=.5)    # end of delay
#             ax.axvline(2.5, color='k', linestyle='--', alpha=.5)  # end of response
#     else:
#         for ax in axs[:, col]:    ax.axvline(-.25, color='k', linestyle='--', alpha=.5)
#     axs[1, col].set(xlim=(trial_half_prestarts[trial_half], trial_half_durs[trial_half]))

# axs[0, 0].set(ylabel='sorted trials'); axs[1, 0].set(ylabel='norm. FR (Hz)')
# axs[1, 0].set(xlabel='time (s)'); axs[1, 1].set(xlabel='time (s)')
# axs[1, 1].legend(loc='lower right', fontsize=8)
# fig.suptitle(f"Sample neuron ({df_neurs.iloc[neur_idx]['region'][2:-1]})", fontweight='bold')
# plt.tight_layout(); plt.show()

# %%
# from pathlib import Path
# from PIL import Image
# base = Path("../../outputs/figs/single-units")
# def pngs_to_pdf(png_paths, out_pdf):
#     imgs = [Image.open(p).convert("RGB") for p in sorted(png_paths)]
#     if not imgs:
#         raise FileNotFoundError(f"No PNGs matched for {out_pdf}")
#     imgs[0].save(out_pdf, save_all=True, append_images=imgs[1:])
# pngs_to_pdf(base.glob("*_trial_halves.png"), base / "trial_halves.pdf")
# pngs_to_pdf(base.glob("*_stim_epoch.png"), base / "stim.pdf")
# pngs_to_pdf(base.glob("*_stim_epoch_tuning_heatmap.png"), base / "cntxt_heatmaps.pdf")
# for x in [1, 2, 3]:
#     ctx_dir = base / f"C{x}"
#     pngs_to_pdf(ctx_dir.glob("*_stim_epoch_tuning_psth.png"), base / f"cntxt{x}_stim_tuning_psth.pdf")
#     pngs_to_pdf(ctx_dir.glob("*_stim_epoch_tuning_lineplot.png"), base / f"cntxt{x}_stim_tuning_lineplot.pdf")
