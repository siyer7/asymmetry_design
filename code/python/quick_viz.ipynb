# %% [markdown]
# df: n_rows = n_subjs, cols = subjID, sess_type, eligibility

# %%
import pandas as pd

# collapse trial-level beh data to one row per subject (each subj ran exactly one sess_type); pilots have NaN eligibility
all_beh_trials_df = pd.read_csv('../../data/psychopy/all_beh_trials_df.csv')
subjs_df = all_beh_trials_df[['subj', 'sess_type', 'eligibility']].drop_duplicates().rename(columns={'subj': 'subjID'}).reset_index(drop=True)
subjs_df
# Out:
#     subjID sess_type    eligibility
# 0   1.1000         A            NaN
# 1   1.1100         B            NaN
# 2   1.1110         C            NaN
# 3   1.1111         D            NaN
# 4   9.0000         A       LFP only
# 5  11.0000         B  behavior only
# 6  12.0000         C       neuronal
# 7  18.0000         D       neuronal
# 8  21.0000         A       neuronal
# 9  22.0000         D       neuronal
