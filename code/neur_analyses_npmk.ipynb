# %%
import numpy as np, matplotlib.pyplot as plt, seaborn as sns, glob, os, scipy.stats as stats
import h5py

# %%
file = h5py.File("../results/202512/workspace.mat", "r")
nev, ns6 = file["NEV"], file["NS6"]

# %%
raw_spikes = nev['Data']['Spikes']['TimeStamp']
raw_spikes.shape
# Out:
# (41571, 1)

# %%
trials_df = pd.read_csv('../results/asymmetry_final_subj-202512_difficulty-patients_order-C_2025-07-26_12h47.29.109.csv')
trials_df
# Out:
#      thisN  thisTrialN  thisRepN  blockN  run  condition  trial_key  \
# 0      0.0         0.0       0.0     1.0  1.0   baseline       21.0
# 1      1.0         1.0       0.0     1.0  1.0   baseline       35.0
# 2      2.0         2.0       0.0     1.0  1.0   baseline       26.0
# 3      3.0         3.0       0.0     1.0  1.0   baseline        5.0
# 4      4.0         4.0       0.0     1.0  1.0   baseline       37.0
# ..     ...         ...       ...     ...  ...        ...        ...
# 236   36.0        36.0       0.0     6.0  2.0  flat_comp      201.0
# 237   37.0        37.0       0.0     6.0  2.0  flat_comp      237.0
# 238   38.0        38.0       0.0     6.0  2.0  flat_comp      217.0
# 239   39.0        39.0       0.0     6.0  2.0  flat_comp      204.0
# 240    NaN         NaN       NaN     NaN  NaN        NaN        NaN
#
#      stim_file_pos  stim_pos  noise_pos  ...  blocks.block_end_resp.duration  \
# ...
