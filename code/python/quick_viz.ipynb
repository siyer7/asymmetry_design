# %% [markdown]
# df: n_rows = n_subjs, cols = subjID, sess_type

# %%
import pandas as pd

# collapse trial-level psychopy data to one row per subject (each subj ran exactly one sess_type)
psychopy_all = pd.read_csv('../../data/psychopy/all_subjs_clean.csv')
subjs_df = psychopy_all[['subj', 'sess_type']].drop_duplicates().rename(columns={'subj': 'subjID'}).reset_index(drop=True)
subjs_df
# Out:
#    subjID sess_type
# 0       9         A
# 1      11         B
# 2      12         C
# 3      18         D
# 4      21         A
# 5      22         D
