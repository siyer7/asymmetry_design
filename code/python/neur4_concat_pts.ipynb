# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns, glob, os

# %% [markdown]
# ### Objective
# 1. Concatenate 2d spike arr, 3d FR arr, and 1d bin arr across patients
# 2. Also create dicts: patient2spikeArr, patient2frArr, patient2binArr
